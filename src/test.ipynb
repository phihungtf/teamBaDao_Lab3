# %%
# import numpy pandas matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
# read data from thuoc_raw.json
df = pd.read_json('thuoc_raw.json')
# print first 5 rows
df.head()
# Out:
#             id images                tenThuoc dotPheDuyet soQuyetDinh  \
# 0  VD-10418-10     []  Amogentine 500mg/125mg         119   42/QĐ-QLD
# 1  VD-10419-10     []                 PQAlevo         119   42/QĐ-QLD
# 2  VD-10420-10     []          Berberin 0,01g         119   42/QĐ-QLD
# 3  VD-10421-10     []          Berberin 0,05g         119   42/QĐ-QLD
# 4  VD-10422-10     []   Doxycyclin TW3 100 mg         119   42/QĐ-QLD
#
#      pheDuyet  hieuLuc     soDangKy                                  hoatChat  \
# 0  24/02/2010      NaN  VD-10418-10  amoxicilin  500mg, acid clavulanic 125mg
# 1  24/02/2010      NaN  VD-10419-10                        levofloxacin 250mg
# 2  24/02/2010      NaN  VD-10420-10                     Berberin clorid 0,01g
# 3  24/02/2010      NaN  VD-10421-10                     Berberin clorid 0,05g
# 4  24/02/2010      NaN  VD-10422-10              Doxycyclin hydroclorid 100mg
#
#   phanLoai  ... nhomThuoc isHide   rate rutSdk rutSdkFile  chuY ten meta rows  \
# 0     None  ...  Tân dược    Yes  018.5      0         []  None NaN   {}   []
# 1     None  ...  Tân dược    Yes  005.0      0         []  None NaN   {}   []
# 2     None  ...  Tân dược    Yes  005.0      0         []  None NaN   {}   []
# 3     None  ...  Tân dược    Yes  005.0      0         []  None NaN   {}   []
# 4     None  ...  Tân dược    Yes  005.0      0         []  None NaN   {}   []
#
#   state
# 0   202
# 1   202
# 2   202
# 3   202
# 4   202
#
# [5 rows x 36 columns]

# %%
class APIRegexHelper:
	def __init__(self, string):
		self.string = string
		
	# remove mass and unit
	def remove_mass_and_unit(self):
		# remove mass
		self.string = re.sub(r'\d+((,|\.)\d+)*\s*(mg|mcg|IU|UI|g|ml|l|kg|mm|\%|đơn vị USP)', '', self.string)
		return self

	# remove leading and trailing spaces
	def remove_space(self):
		self.string = self.string.strip()
		return self

	# remove all the string after the first parenthesis
	def remove_parenthesis(self):
		self.string = re.sub(r'(\(|\)).*', '', self.string)
		return self
	
	# remove all the slash
	def remove_slash(self):
		self.string = re.sub(r'\s*/', '', self.string)
		return self

	# remove all the string before the first colon
	def remove_colon(self):
		self.string = re.sub(r'.*:', '', self.string)
		return self
	
	# remove ratio
	def remove_ratio(self):
		self.string = re.sub(r'\d+:\d+', '', self.string)
		return self
	
	# remove line break
	def remove_line_break(self):
		self.string = re.sub(r'\n', '', self.string)
		return self
	
	# to lower case
	def to_lower_case(self):
		self.string = self.string.lower()
		return self
	
	# remove similar strings
	def remove_similar_string(self):
		self.string = re.sub(r'(tương đương|tương ứng|dưới dạng|dạng).*', '', self.string)
		return self

class UltimateAPIRegex:
	def __init__(self, string):
		self.string = string
		self.apis = []
		
	def get_apis(self):
		# split by comma or semicolon that not followed by digit
		temp_list = re.split(r'(,|;)\s*(?![0-9])', self.string)
		for s in temp_list:
			temp = APIRegexHelper(s) \
					.remove_line_break() \
					.remove_mass_and_unit() \
			 		.remove_parenthesis() \
					.remove_ratio() \
			 		.remove_colon() \
			 		.remove_slash() \
					.remove_similar_string() \
					.remove_space() \
					.to_lower_case()					
			self.apis.append(temp.string)
		self.remove_incorrect_string().add_vitamin()
		return self.apis
	
	# remove incorrect strings
	def remove_incorrect_string(self):
		incorrect_strings = [';', '(', ')', ':', '', ' ', ',', '...', '--', '…']
		self.apis = [s for s in self.apis if s not in incorrect_strings]
		return self

	# add vitamin
	def add_vitamin(self):
		for i in range(len(self.apis)):
			if len(self.apis[i]) <= 2:
				self.apis[i] = 'vitamin ' + self.apis[i]
		return self

# %%
hoatChat = df['hoatChat'].tolist()
api_list = []
for s in hoatChat:
	api = UltimateAPIRegex(s).get_apis()
	api_list.append(api)
api_list
# Out:
# [['amoxicilin', 'acid clavulanic'],
#  ['levofloxacin'],
#  ['berberin clorid'],
#  ['berberin clorid'],
#  ['doxycyclin hydroclorid'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['tetracyclin'],
#  ['thiamin nitrat'],
#  ['ích mẫu', 'hương phụ', 'ngải cứu'],
#  ['adrenalin'],
#  ['alpha chymotrypsin'],
#  ['cefradin'],
#  ['cimetidin'],
#  ['biphenyl dimethyl dicarboxylat'],
#  ['colchicin'],
#  ['ephedrin hydroclorid'],
#  ['ezetimibe'],
#  ['famciclovir'],
#  ['famciclovir'],
#  ['hyaluronidase'],
#  ['piracetam'],
#  ['lincomycin'],
#  ['galantamin hydrobromid'],
#  ['nước cất pha tiêm'],
#  ['nước cất pha tiêm'],
#  ['nofloxacin'],
#  ['orlistat'],
#  ['ouabain'],
#  ['papaverin hydroclorid'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['piracetam'],
#  ['methyl prednisolon'],
#  ['pravastatin natri'],
#  ['pravastatin natri'],
#  ['ciprofloxacin'],
#  ['seratiopeptidase'],
#  ['acid tranexamic'],
#  ['cefoperazon am'],
#  ['acid acetylsalicylic'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['cetirizin hcl'],
#  ['acid ascorbic'],
#  ['diazepam'],
#  ['domperidon'],
#  ['cyanocobalamin'],
#  ['gentamicin'],
#  ['gentamicin'],
#  ['gentamicin'],
#  ['griseofulvin'],
#  ['indomethacin'],
#  ['lincomycin'],
#  ['magnesi lactat dihdrat', 'pyridoxin hydroclorid'],
#  ['morphin hydroclorid'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['prednison'],
#  ['spiramycin'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['l-lysin hcl', 'vitamin b1', 'vitamin b6', 'b12'],
#  ['acid  ascorbic'],
#  ['vitamin c', 'natri ascorbat'],
#  ['acid  ascorbic'],
#  ['cefuroxim natri'],
#  ['ceftazidime'],
#  ['ceftriaxone'],
#  ['cao nhân sâm. các vitamin và khoángchất'],
#  ['cefadroxil'],
#  ['cefuroxim natri'],
#  ['cefuroxime'],
#  ['cefuroxim'],
#  ['ciprofloxacin'],
#  ['dexamethason acetat', 'chloramphenicol'],
#  ['enalapril maleat'],
#  ['enalapril maleat'],
#  ['cao khô ginkgo biloba'],
#  ['metformin.hcl'],
#  ['prednisolone'],
#  ['prednisolone'],
#  ['terpin hydrat', 'natri benzoat'],
#  ['paracetamol', 'vitamin c'],
#  ['paracetamol', 'vitamin c'],
#  ['paracetamol', 'clorpheniramin maleat', 'dextromethorphan .hbr'],
#  ['paracetamol', 'ibuprofen'],
#  ['vitamin a', 'vitamin e'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['vitamin  b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin pp', 'vitamin c'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b6', 'vitamin c', 'vitamin pp'],
#  ['clopidogrel bisulfat'],
#  ['amoxicilin trihydrat'],
#  ['amoxicilin trihydrat'],
#  ['cephalexin monohydrat'],
#  ['cephalexin monohydrat'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['cefixim trihydrat'],
#  ['paracetamol', 'lidocain'],
#  ['cefpodoxim proxetil'],
#  ['vitamin b1', 'vitamin b6', 'vitamin b12'],
#  ['thiamin  hydroclorid', 'pyridoxin hydroclorid', 'cyanocobalamin'],
#  ['thiamin  hydroclorid', 'pyridoxin hydroclorid', 'cyanocobalamin'],
#  ['alpha chymotrypsin', 'dextran', 'mannitol'],
#  ['dibencozide'],
#  ['thục địa',
#   'sơn thù du',
#   'bạch linh',
#   'ngũ vị tử',
#   'hoài sơn',
#   'mẫu đơn bì',
#   'trạch tả',
#   'mạch môn'],
#  ['arginin tidiaciat'],
#  ['colchicin'],
#  ['bạch chỉ',
#   'xuyên khung',
#   'hương phụ',
#   'quế',
#   'cam thảo',
#   'gừng khô',
#   'xạ căn'],
#  ['magnesi valproat'],
#  ['almitrin bismesylat', 'raubasin'],
#  ['l-ornithin l-aspartat'],
#  ['cao cardus marianus',
#   'thiamin hcl',
#   'pyridoxin hcl',
#   'nicotinamid',
#   'riboflavin'],
#  ['cao nhân sâm',
#   'lô hội',
#   'vitamin a',
#   'vitamin d3',
#   'vitamin e',
#   'vitamin c',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b5',
#   'vitamin b6',
#   'vitamin pp',
#   'b12',
#   'sắt',
#   'đồng'],
#  ['ciprofloxacin hydroclorid monohydrat'],
#  ['thiamin mononitrat', 'pyridoxin hydroclorid', 'cyanocobalamin'],
#  ['azithromycin dihydrat'],
#  ['thiamin mononitrat', 'pyridoxin hydroclorid', 'cyanocobalamin'],
#  ['piracetam'],
#  ['roxithromycin'],
#  ['silymarin'],
#  ['silymarin',
#   'cao diệp hạ châu',
#   'cao ngũ vị tử',
#   'cao nhân trần',
#   'curcumin'],
#  ['dextromethorphan hbr', 'terpin hydrat'],
#  ['ciprofloxacin'],
#  ['betamethason dipropionat', 'gentamycin base', 'clotrimazol'],
#  ['metformin hcl'],
#  ['vitamin c', 'glucose'],
#  ['hum-rec epidermal growth factor', 'sulfadiazin bạc am'],
#  ['cloramphenicol', 'hydrocortison acetat'],
#  ['natri clorid'],
#  ['acid fusidic', 'betamethason valerat'],
#  ['promethazin hydroclorid'],
#  ['acid fusidic'],
#  ['paracetamol', 'loratadin', 'dextromethorphan hydrobromid'],
#  ['erythromycin ethyl succinat', 'sulfamethoxazol', 'trimethoprim'],
#  ['erythromycin ethyl succinat'],
#  ['betamethason dipropionat'],
#  ['atorvastatin calcium trihydrat'],
#  ['atorvastatin calcium trihydrat'],
#  ['paracetamol', 'codein phosphate'],
#  ['hương phụ', 'ích mẫu', 'ngải cứu'],
#  ['berberin hydroclorid'],
#  ['calci ascorbat'],
#  ['calci ascorbat'],
#  ['nhôm phosphat gel'],
#  ['meloxicam'],
#  ['ranitidin hcl'],
#  ['ranitidin hcl'],
#  ['testosteron undecanoat'],
#  ['l-arginin hydroclorid'],
#  ['atropin sulfat'],
#  ['cafein'],
#  ['diclofenac natri'],
#  ['cao  cardus marianus',
#   'vitamin b1',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin b2',
#   'vitamin b5'],
#  ['cao cardus marianus',
#   'cao diệp hạ châu',
#   'vitamin b1',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin b2',
#   'vitamin b5'],
#  ['sắt', 'vitamin c', 'vitamin b9', 'vitamin b12', 'đồng sulfat'],
#  ['natri clorid'],
#  ['nước cất tiêm'],
#  ['nước cất tiêm'],
#  ['procain hydroclorid'],
#  ['strychnin sulfatml'],
#  ['paracetamol'],
#  ['acetaminofen', 'loratadin', 'dextromethorphan hbr'],
#  ['acetaminophen', 'phenylephrin hcl', 'dextromethorphan hbr'],
#  ['sắt fumarat', 'acid folic', 'vitamin b12'],
#  ['cao  cardus marianus',
#   'vitamin b1',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin b2',
#   'vitamin b5'],
#  ['thyamin hydroclorid'],
#  ['acid  ascorbic'],
#  ['aluminium hydroxide gel khô usp',
#   'magnesium  hydroxide usp',
#   'simethicone usp'],
#  ['acetyl cystein'],
#  ['clorpheniramin maleat'],
#  ['thiamin mononitrat',
#   'riboflavin',
#   'pyridoxin hcl',
#   'nicotinamid',
#   'calci pantothenat'],
#  ['thiamin mononitrat',
#   'riboflavin',
#   'pyridoxin hcl',
#   'nicotinamid',
#   'calci pantothenat'],
#  ['prednisolon'],
#  ['thiamin mononitrat'],
#  ['amlodipin base'],
#  ['berberin clorid'],
#  ['biotin'],
#  ['bách bộ'],
#  ['carbimazol'],
#  ['cao actiso', 'cao diệp hạ châu'],
#  ['cao khô bạch quả'],
#  ['cao actiso'],
#  ['trimebutin maleat'],
#  ['omeprazol'],
#  ['cinarizin'],
#  ['tetracyclin'],
#  ['vitamin  b1', 'vitamin b6', 'vitamin b12'],
#  ['thiamin nitrat'],
#  ['thiamin nitrat'],
#  ['acid  ascorbic'],
#  ['vitamin  b1', 'vitamin b6', 'vitamin b2', 'vitamin pp', 'vitamin b5'],
#  ['dexamethason natri phosphat'],
#  ['nikethamide'],
#  ['artemether', 'lumefantrin'],
#  ['artesunat'],
#  ['artesunate'],
#  ['dextromethorphan hbr', 'chlorpheniramin maleate', 'guaifenesin'],
#  ['cefotaxim'],
#  ['sodium bicarbonat', 'sodium chloride  trong  dung dịch đậm đặc'],
#  ['artemether', 'lumefantrin'],
#  ['l- isoleucin',
#   'l-lysin hydrochlorid',
#   'l-tryptophan',
#   'l-threonin',
#   'l-valin',
#   'l-phenylalanin',
#   'l-methionin',
#   'l-leucin',
#   'glycin',
#   'l-arginin hydrochlorid',
#   'l-histidin hydrochlorid monohydrat',
#   'xylitol'],
#  ['cefadroxil'],
#  ['ferrous sulphate',
#   'glycin',
#   'l- histidine hydrochloride',
#   'l-lysine hydrochloride…'],
#  ['ferrous fumarat', 'l-histidin hydrochlorid'],
#  ['ceftriaxon'],
#  ['paracetamol', 'codein phosphat'],
#  ['menthol', 'eucalyptol'],
#  ['piroxicam'],
#  ['pyrazinamid'],
#  ['sodium fluoride'],
#  ['sodium chlorid'],
#  ['terpin hydrat'],
#  ['terpin hydrat', 'dextromethorphan hydrobromid', 'sodium benzoate'],
#  ['terpin hydrat', 'codein'],
#  ['acid ascorbic',
#   'ergocalciferol',
#   'nicotinamid',
#   'riboflavin',
#   'thiamin nitrat',
#   'retinol palmitat'],
#  ['amikacin sulfat'],
#  ['cephalexin'],
#  ['cephalexin'],
#  ['cephalexin'],
#  ['cefixim trihydrat'],
#  ['etodolac'],
#  ['etodolac'],
#  ['gabapentin'],
#  ['piroxicam'],
#  ['acid tranexamic'],
#  ['cephalexin'],
#  ['cephalexin'],
#  ['piroxicam'],
#  ['captopril'],
#  ['atenolol', 'amlodipin besylat'],
#  ['nabumeton'],
#  ['cefaclor monohydrat'],
#  ['cefradin'],
#  ['ciprofloxacin hcl'],
#  ['paracetamol'],
#  ['acetaminofen'],
#  ['acetaminophen'],
#  ['timolol maleat'],
#  ['timolol maleat'],
#  ['vancomycin hydroclorid'],
#  ['vancomycin hydroclorid'],
#  ['vitamin a', 'vitamin d'],
#  ['nước cất pha tiêm'],
#  ['clidinium br', 'chlordiazepoxide'],
#  ['tibolone'],
#  ['meloxicam'],
#  ['vitamin  b1', 'vitamin b6', 'vitamin b12'],
#  ['vitamin c',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b5',
#   'vitamin b6',
#   'b12',
#   'vitamin pp',
#   'vitamin b9',
#   'vitamin b8',
#   'vitamin e',
#   'kẽm',
#   'đồng'],
#  ['dihydroergotamin mesylat'],
#  ['bạch tật lê'],
#  ['paracetamol', 'ibuprofen'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['acid ascorbic',
#   'retinol  palmitat',
#   'alpha tocopherol acetat',
#   'thiamin nitrat',
#   'riboflavin natri phosphat',
#   'pyridoxin.hcl',
#   'nicotinamid',
#   'calci pantothenat',
#   'acid folic'],
#  ['salbutamol sulfat'],
#  ['acyclovir'],
#  ['meloxicam'],
#  ['meloxicam'],
#  ['propyl thio uracil'],
#  ['cao khô hoàng liên', 'bột mộc hương'],
#  ['domperidone'],
#  ['domperidon maleat'],
#  ['cinarizin'],
#  ['betamethason dipropionat', 'gentamycin sulphat', 'clotrimazol'],
#  ['cao đặc hà thủ ô'],
#  ['ampicilin trihydrat compacted'],
#  ['atorvastatin'],
#  ['bromhexin hydroclorid'],
#  ['cefadroxil monohydrate compacted'],
#  ['cefixim trihydrat'],
#  ['clarithromycin'],
#  ['cloxacillin sodium compacted'],
#  ['dibencozid'],
#  ['bisoprolol fumarat'],
#  ['paracetamol', 'chlorpheniramin maleat', 'thiamin hcl'],
#  ['acyclovir'],
#  ['kẽm gluconat'],
#  ['paracetamol', 'clorpheniramin maleat'],
#  ['enalapril maleat'],
#  ['fenofibrat micronised'],
#  ['glipizide'],
#  ['methionin'],
#  ['ofloxacin'],
#  ['pantoprazol sodium sesquihydrat'],
#  ['paracetamol', 'thiamin hydroclorid', 'clorpheniramin maleat'],
#  ['rifampicin'],
#  ['đồng sulphat', 'natri fluorid'],
#  ['alverin citrat', 'simethicon'],
#  ['sorbitol'],
#  ['codein base', 'terpin hydrat'],
#  ['paracetamol', 'codeine phosphate'],
#  ['menthol', 'eucalyptol', 'camphor', 'methyl salicylat'],
#  ['menthol', 'eucalyptol', 'camphor', 'methyl salicylat'],
#  ['acetyl - dl leucin'],
#  ['cao ginkgo biloba'],
#  ['acyclovir'],
#  ['acyclovir'],
#  ['candesartan cilexetil'],
#  ['cetirizin dihydroclorid'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['sulphamethoxazol', 'trimethoprim'],
#  ['efavirenz'],
#  ['enalapril maleat'],
#  ['irbesartan'],
#  ['atorvastatin calci'],
#  ['metformin hcl'],
#  ['metformin hcl'],
#  ['metronidazol'],
#  ['metronidazol'],
#  ['stavudin', 'lamivudin', 'nevirapin'],
#  ['risedronat natri'],
#  ['ciprofloxacin'],
#  ['serratiopeptidase'],
#  ['gliclazid'],
#  ['alfuzosin hydrochlorid'],
#  ['racecadotril'],
#  ['paracetamol', 'cafein', 'phenylephedrin hcl'],
#  ['paracetamol', 'cafein'],
#  ['retinyl palmitat',
#   'thiamin nitrat',
#   'riboflavin',
#   'nicotinamid',
#   'acid ascorbic',
#   'acid folic',
#   'calci pantothenat',
#   'cyanocobalamin',
#   'pyridoxin hcl',
#   'dl-alpha tocopheryl acetat',
#   'cholecalciferol'],
#  ['arginin hcl'],
#  ['arginin hcl'],
#  ['arginin tidiacicat', 'vitamin c', 'vitamin b1', 'vitamin b2'],
#  ['ambroxol hcl'],
#  ['loratadin', 'pseudoephedrin hcl'],
#  ['cetirizin dihydroclorid'],
#  ['metformin hcl'],
#  ['celecoxib'],
#  ['nifuroxazide'],
#  ['fenofibrat'],
#  ['fenofibrat'],
#  ['paracetamol', 'pseudoephedrin hcl'],
#  ['clarithromycin'],
#  ['tadalafil'],
#  ['tadalafil'],
#  ['sibutramin hcl monohydrat'],
#  ['glimepirid'],
#  ['paracetamol', 'cafein'],
#  ['tyrothricin'],
#  ['acemetacin'],
#  ['nhôm phosphat gel'],
#  ['dibencozid'],
#  ['losartan kali'],
#  ['losartan kali', 'hydroclorothiazid'],
#  ['nebivolol'],
#  ['paracetamol', 'pseudoephedrin hcl', 'clorpheniramin maleat'],
#  ['rabeprazol natri'],
#  ['cinnarizine'],
#  ['loratadin'],
#  ['ciprofloxacin hydroclorid monohydrat'],
#  ['meloxicam'],
#  ['desloratadin'],
#  ['glimepirid'],
#  ['amisulpirid'],
#  ['levofloxacin hemihydrat'],
#  ['omeprazol magnesi'],
#  ['omeprazol magnesi'],
#  ['amisulpirid'],
#  ['vitamin e', 'vitamin c', 'vitamin b1', 'b2…'],
#  ['cefmetazol  am'],
#  ['ambroxol', 'clenbuterol hcl'],
#  ['bacitracin', 'neomycin', 'polymyxin b'],
#  ['clotrimazol'],
#  ['ceftezol am'],
#  ['tiropramid hcl'],
#  ['ceftizoxim am'],
#  ['amitriptylin hydroclorid'],
#  ['enalapril maleat'],
#  ['glibenclamid', 'metformin hydroclorid'],
#  ['methyl prednisolon'],
#  ['pregabalin'],
#  ['retinol',
#   'thiamin hydroclorid',
#   'riboflavin natri phosphat',
#   'pyridoxin hcl',
#   'cyanocobalamin',
#   'acid ascorbic',
#   'cholecalciferol',
#   'alpha tocopheryl acetat',
#   'nicotinamid',
#   'calci d-patothenat'],
#  ['thiamin hydroclorid', 'pyridoxin hydroclorid', 'cyanocobalamin'],
#  ['cao nhân sâm',
#   'cao bạch quả',
#   'retinol palmitat',
#   'cholecalciferol',
#   'tocopherol acetat',
#   'acid ascobic',
#   'thiamin nitrar',
#   'pyridoxin hcl',
#   'riboflavin',
#   'nicotinamid',
#   'cyanocobanlamin',
#   'acid folic',
#   'biotin',
#   'dexpenthenol',
#   'calci glycerophosphat',
#   'magnesi glycerophosphat...'],
#  ['allopurinol'],
#  ['acid folic'],
#  ['methocarbamol'],
#  ['cao  carduus marianus',
#   'thiamin hcl',
#   'pyridoxin hcl',
#   'nicotinamid',
#   'riboflavin',
#   'calci pantothenat',
#   'cyanocobanlamin'],
#  ['dịch chiết nhân sâm trắng'],
#  ['ethanol'],
#  ['ampicilin trihydrat'],
#  ['levofloxacin hemihydrat'],
#  ['acemetacin'],
#  ['paracetamol', 'ibuprofen'],
#  ['cephaclor  monohydrat'],
#  ['clozapin'],
#  ['eprazinon dihydroclorid'],
#  ['cefaclor  monohydrat'],
#  ['paracetamol'],
#  ['serratiopeptidase'],
#  ['nystatin'],
#  ['roxithromycin'],
#  ['alverin citrat'],
#  ['spiramycin'],
#  ['terpin hydrat', 'codein base'],
#  ['terpin hydrat', 'codein base'],
#  ['tetracyclin hydroclorid'],
#  ['selen trong nấm mem khô',
#   'acid ascorbic',
#   'hỗn dịch beta-caroten',
#   'dl anpha tocopherol'],
#  ['cao khô crataegus', 'cao lá melissa', 'cao lá bạch quả', 'dầu tỏi'],
#  ['thiamin nitrat', 'pyridoxin hydroclorid', 'cyanocobalamin'],
#  ['myrtol'],
#  ['myrtol'],
#  ['l-ornithine l-aspartate', 'tocopherol acetate'],
#  ['dl-alpha tocopherol acetat',
#   'hỗn dịch beta-carotene',
#   'ubidecarenone',
#   'oxyd kẽm',
#   'bột selen',
#   'acid ascorbic'],
#  ['biotin'],
#  ['dexclopheniramin maleat', 'betamethason'],
#  ['paracetamol',
#   'pseudo ephedrin hydroclorid',
#   'dextromethorphan hbr',
#   'clorpheniramin maleat'],
#  ['lansoprazole'],
#  ['triprolidin hcl', 'pseudoephedrin hcl'],
#  ['lysozym hydroclorid'],
#  ['lysozym hydroclorid'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b5', 'vitamin b6', 'vitamin pp'],
#  ['vitamin b1', 'vitamin b2', 'vitamin b5', 'vitamin b6', 'vitamin pp'],
#  ['diphenhydramin hydroclorid'],
#  ['diphenhydramin hydroclorid'],
#  ['pancreatin', 'amylase', 'proteasa'],
#  ['l- cystine'],
#  ['paracetamol', 'loratadin', 'dextromethorphan hydrobromid'],
#  ['paracetamol', 'pseudoephedrin hcl', 'dextromethorphan'],
#  ['flunarizin'],
#  ['flunarizin'],
#  ['flunarizin'],
#  ['prednisolon'],
#  ['prednisolon'],
#  ['lovastatin'],
#  ['lovastatin'],
#  ['l-arginin hydroclorid',
#   'thiamin mononitrat',
#   'pyridoxin hydroclorid',
#   'cyanocobalamin'],
#  ['piracetam'],
#  ['paracetamol'],
#  ['terpin hydrat', 'dexromethorphan hydrobromid'],
#  ['acetaminophen'],
#  ['vitamin d3', 'calci', 'magnesium gluconate', 'fructose oligosaccharide'],
#  ['acetaminophen', 'phenylephrine hcl'],
#  ['metformin hcl'],
#  ['metformin'],
#  ['acetylcystein'],
#  ['acetyl cystein'],
#  ['acetylcystein'],
#  ['l-ornithin l-aspartat'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['lincomycin'],
#  ['mebendazol'],
#  ['terpin hydrat', 'dextromethorphan hydrobromid'],
#  ['tetracyclin hydroclorid'],
#  ['tadalafil'],
#  ['thiamin  hydroclorid',
#   'pyridoxin hydroclorid',
#   'nicotinamid',
#   'riboflavin'],
#  ['thiamin nitrat'],
#  ['thiamin nitrat'],
#  ['riboflavin'],
#  ['pyridoxin hydroclorid'],
#  ['sulpirid'],
#  ['cefixim trihydrat'],
#  ['cefixim trihydrat'],
#  ['berberin clorid'],
#  ['fexofenadin hydroclorid'],
#  ['cefixim trihydrat'],
#  ['cefixim trihydrat'],
#  ['clorpheniramin maleat'],
#  ['clorpheniramin maleat'],
#  ['clorpheniramin maleat'],
#  ['dexamethason acetat'],
#  ['dexamethason acetat'],
#  ['fexofenadin hcl'],
#  ['cefixim trihydrat'],
#  ['cefixim trihydrat'],
#  ['alimemazin tartrat'],
#  ['cefuroxim acetil'],
#  ['thương truật', 'hậu phác', 'trần bì', 'cam thảo', 'gừng'],
#  ['vitamin a',
#   'vitamin d3',
#   'vitamin e',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin c',
#   'l-lysin hydroclorid'],
#  ['hoài sơn', 'sơn thù', 'mẫu đơn bì', 'thục địa', 'trạch tả', 'phục linh'],
#  ['paracetamol',
#   'pseudo ephedrin hydroclorid',
#   'dextromethorphan hbr',
#   'clorpheniramin maleat'],
#  ['clobetasol propionat'],
#  ['fluconazol'],
#  ['ké  đầu ngựa',
#   'tân di hoa',
#   'bạch chỉ',
#   'bạc hà',
#   'hoàng kỳ',
#   'bạch truật',
#   'phòng phong',
#   'kim ngân hoa'],
#  ['vitamin a',
#   'vitamin d3',
#   'vitamin e',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin c',
#   'pp và các acid amin'],
#  ['azithromycin base'],
#  ['artesunate'],
#  ['cao nhân sâm', 'các vitamin và chất khoáng'],
#  ['vitamin a',
#   'vitamin d2',
#   'vitamin e',
#   'vitamin b6',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin c',
#   'vitamin pp',
#   'acid folic'],
#  ['betamethason dipropionat', 'gentamycin sulfat', 'clotrimazol'],
#  ['vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'b12',
#   'vitamin pp',
#   'cao nhân sâm'],
#  ['cao nhân sâm', 'lô hội', 'các vitamin và khoáng chất'],
#  ['calci gluconat',
#   'vitamin d3',
#   'vitamin e',
#   'vitamin c',
#   'magnesium',
#   'kẽm'],
#  ['artemether', 'lumefantrine'],
#  ['l-leucin',
#   'l-isoleucin',
#   'l-lysin hydroclorid',
#   'l-phenylalanin',
#   'l-threonin',
#   'l-valin',
#   'l-tryptophan',
#   'l-methionin',
#   'vitamin a',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin e',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin c',
#   'vitamin d3',
#   'acid folic'],
#  ['acetyl spiramycin', 'metronidazol'],
#  ['pefloxacin mesylate dihydrate'],
#  ['coenzym q10', 'vitamin a', 'vitamin e', 'vitamin c', 'selen'],
#  ['cao bạch quả',
#   'vitamin a',
#   'vitamin d3',
#   'vitamin b9',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b5',
#   'vitamin b6',
#   'vitamin c',
#   'vitamin e',
#   'vitamin pp'],
#  ['prednisolon'],
#  ['cinnarizin'],
#  ['ofloxacin'],
#  ['natri citicoline'],
#  ['acetaminophen', 'ibuprofen'],
#  ['magnesi lactat dihydrat', 'vitamin b6'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['dexclorpheniramin maleat'],
#  ['chloramphenicol', 'dexamethason'],
#  ['paracetamol', 'loratadin', 'dextromethorphan hydrobromid'],
#  ['hoài sơn',
#   'liên nhục',
#   'liên tâm',
#   'bá tử nhân',
#   'hắc táo nhân',
#   'lá dâu',
#   'lá vông',
#   'long nhãn'],
#  ['diệp hạ châu đắng'],
#  ['furosemid'],
#  ['metformin hydroclorid'],
#  ['macrogol 4000'],
#  ['attapulgit hoạt hóa',
#   'gel aluminium hydroxyde và magnesium carbonate sấy khô'],
#  ['piracetam'],
#  ['vitamin a',
#   'vitamin e',
#   'vitamin d3',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin c',
#   'b12',
#   'nicotinamid'],
#  ['terpin hydrat', 'codein base', 'natri benzoat'],
#  ['glucose khan', 'natri clorid', 'kali clorid', 'natri citrat'],
#  ['acetylcystein'],
#  ['acetylcystein'],
#  ['paracetamol', 'phenylephdrin hydroclorid', 'pheniramin maleat'],
#  ['lysin hcl',
#   'calci',
#   'phospho',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin e',
#   'vitamin pp'],
#  ['cefixim trihydrat'],
#  ['cephalexin monohydrat'],
#  ['clarithromycin'],
#  ['amoxicilin trihydrat', 'clavulanate potassium &silicone dioxide'],
#  ['eucalyptol', 'tinh dầu tràm', 'tinh dầu gừng', 'tinh dầu tần', 'menthol'],
#  ['sắt fumarat', 'acid folic', 'vitamin b12'],
#  ['vitamin a',
#   'vitamin c',
#   'vitamin d3',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin pp',
#   'vitamin b6',
#   'b12',
#   'acid folic',
#   'calci lactat',
#   'sắt fumarat',
#   'đồng sulfat'],
#  ['thiamin  hydroclorid',
#   'riboflavin',
#   'pyridoxin hydroclorid',
#   'calci gluconat  trong  chế phẩm'],
#  ['alpha - terpineol'],
#  ['eucalyptol', 'tinh dầu tràm', 'tinh dầu gừng', 'tinh dầu tần', 'menthol'],
#  ['paracetamol', 'pseudoephedrin hcl'],
#  ['paracetamol', 'codein phosphat'],
#  ['paracetamol', 'vitamin c'],
#  ['thiamin mononitrat',
#   'vitamin b2',
#   'vitamin b5',
#   'vitamin b6',
#   'vitamin pp'],
#  ['omeprazol'],
#  ['spiramycin'],
#  ['cao khô kim tiền thảo'],
#  ['l arginin hcl'],
#  ['seratiopeptidase'],
#  ['serratiopeptidase'],
#  ['clorpheniramin maleat'],
#  ['erythromycin'],
#  ['vitamin  b1', 'vitamin b6', 'vitamin b12'],
#  ['vitamin  b1', 'vitamin b6', 'vitamin b12'],
#  ['vitamin c'],
#  ['vitamin c'],
#  ['natri borat'],
#  ['spiramycin'],
#  ['metformin hydroclorid'],
#  ['clorpheniramin maleat'],
#  ['celecoxib'],
#  ['esomeprazol pellets'],
#  ['enalapril maleat'],
#  ['enalapril maleat'],
#  ['metronidazol', 'spiramycin'],
#  ['metformin hcl'],
#  ['metformin hcl'],
#  ['esomeprazol pellets'],
#  ['phloroglucinol dihydrat', 'trimethyl phloroglucinol'],
#  ['spiramycin 1,5 m.iu'],
#  ['omeprazol magnesi'],
#  ['ibuprofen'],
#  ['amoxicillin trihydrat', 'kali clavulanat'],
#  ['ceftazidim pentahydrat'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['cefoperazon natri'],
#  ['paracetamol', 'pseudoephedrin hcl', 'loratadin'],
#  ['nikethamide', 'glucose'],
#  ['cao ginkgo biloba'],
#  ['cao ginkgo biloba'],
#  ['betahistin dihydroclorid'],
#  ['betahistin dihydroclorid'],
#  ['omeprazol pellets'],
#  ['ceterizin dihydroclorid'],
#  ['perindopril tertbutylamin', 'indapamid'],
#  ['diclofenac natri'],
#  ['sắt', 'mangan', 'đồng'],
#  ['vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin d3',
#   'vitamin e',
#   'vitamin pp',
#   'd-panthenol',
#   'phospho',
#   'calci',
#   'lysin hydroclorid'],
#  ['paracetamol'],
#  ['vitamin a',
#   'vitamin c',
#   'vitamin e',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin b5',
#   'acid folic'],
#  ['lansoprazol'],
#  ['rabeprazol natri'],
#  ['seratiopeptidase'],
#  ['lysozym hcl'],
#  ['cetirizin hydrochlorid'],
#  ['cimetidin'],
#  ['cimetidin'],
#  ['lysozyme clorid'],
#  ['serratiopeptidase'],
#  ['than hoạt thảo mộc'],
#  ['prednison'],
#  ['sắt', 'acid folic'],
#  ['nystatin'],
#  ['paracetamol', 'codein phosphat'],
#  ['calcium glucoheptonat',
#   'calcium gluconat',
#   'acid ascorbic',
#   'nicotinamid',
#   'ergocalciferol'],
#  ['calcium glucoheptonat',
#   'calcium gluconat',
#   'acid ascorbic',
#   'nicotinamid',
#   'ergocalciferol'],
#  ['cefpodoxim proxetil'],
#  ['cefpodoxim proxetil'],
#  ['calcium bromid am', 'cloral hydrat am'],
#  ['cephalexin monohydrat'],
#  ['cephalexin mono hydrat'],
#  ['amoxicilin trihydrat'],
#  ['ciprofloxacin hydroclorid'],
#  ['ciprofloxacin hcl'],
#  ['cefadroxil monohydrat'],
#  ['cefadroxil monohydrat'],
#  ['amo xicilin trihydrat', 'acid clavulanic'],
#  ['amoxicilin trihydrat', 'kali clavulanat'],
#  ['mebendazol'],
#  ['mebendazol'],
#  ['gliclazid'],
#  ['ibuprofen'],
#  ['ofloxacin'],
#  ['phenoxymethyl penicilin kali'],
#  ['terpin hydrat', 'natri benzoat', 'codein'],
#  ['spiramycin', 'metronidazole'],
#  ['cefuroxim acetil'],
#  ['calci gluconat', 'vitamin d3'],
#  ['sildenafil citrat'],
#  ['sildenafil citrat'],
#  ['paracetamol'],
#  ['amo xicilin trihydrat', 'kali clavulanat'],
#  ['bari sulfat'],
#  ['bari sulfat'],
#  ['manthol',
#   'tinh dầu bạc hà',
#   'tinh dầu đinh hương',
#   'tinh dầu quế',
#   'tinh dầu long não',
#   'tinh dầu tràm',
#   'methyl salicylat'],
#  ['natri diclofenac', 'methyl salicylat'],
#  ['amo xicilin trihydrat'],
#  ['fluoxetin hydroclorid'],
#  ['magnesi trisilicat', 'nhôm hydroxid'],
#  ['gliclazid'],
#  ['neomycin sulfat', 'naphazolin nitrat', 'betamethason natri phosphat'],
#  ['cao cardus marianus',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b5',
#   'vitamin b6',
#   'vitamin pp'],
#  ['fluocinolon acetonide', 'neomycin sulfat'],
#  ['cephalexin monohydrat'],
#  ['cao nhân sâm',
#   'vitamin a',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin d3',
#   'vitamin b2',
#   'vitamin e',
#   'vitamin b5',
#   'vitamin c',
#   'acid folic',
#   'calci',
#   'magnesi',
#   'đồng',
#   'kali',
#   'sắt',
#   'kẽm',
#   'mangan'],
#  ['lansoprazol', 'clarithromycin', 'tinidazol'],
#  ['vitamin b1'],
#  ['vitamin pp'],
#  ['cefadroxil'],
#  ['chlorpheniramin maleat'],
#  ['cephradin'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['amoxicilin'],
#  ['cephalexin'],
#  ['trimeprazin'],
#  ['metformin hcl'],
#  ['cephalexin'],
#  ['vitamin a', 'vitamin d3'],
#  ['cao bạch quả'],
#  ['desloratadin', 'pseudoephedrin hcl'],
#  ['pancreatin', 'dimethicon'],
#  ['ursodesoxycholic acid', 'thiamin nitrat', 'riboflavin'],
#  ['húng chanh', 'núc nác', 'cineol'],
#  ["cytidine-5'-disodium monophosphate", "uridine-5'-trisodium triphosphate"],
#  ['sinh địa',
#   'đỗ trọng',
#   'nhân sâm',
#   'câu kỷ tử',
#   'ba kích',
#   'đương quy',
#   'hoàng kỳ',
#   'cúc hoa',
#   'liên nhục...'],
#  ['acetaminophen', 'codein phosphat'],
#  ['acid acetyl salicylic'],
#  ['risedronat natri'],
#  ['chymotrypsin'],
#  ['salbutamol sulfat', 'guaifenesin'],
#  ['irbesartan'],
#  ['amiodaron hydroclorid'],
#  ['ivermectin'],
#  ['atorvastatin'],
#  ['atorvastatin'],
#  ['vitamin a',
#   'vitamin c',
#   'vitamin d3',
#   'vitamin e',
#   'vitamin k',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin pp',
#   'vitamin b6',
#   'b12',
#   'vitamin b5',
#   'biotin',
#   'acid folic và các khoáng chất'],
#  ['amiodaron hcl'],
#  ['gliclazid'],
#  ['metformin hcl'],
#  ['l-ornithin l-aspartat'],
#  ['irbesartan'],
#  ['amlodipin'],
#  ['amlodipin'],
#  ['cinarizin'],
#  ['vitamin a',
#   'vitamin d3',
#   'vitamin c',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'b12',
#   'vitamin pp',
#   'vitamin b5',
#   'acid folic',
#   'calci',
#   'sắt',
#   'đồng',
#   'iodid'],
#  ['oxomemazin hcl', 'guaifenesin', 'paracetamol', 'natri benzoat'],
#  ['kẽm',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'b12',
#   'vitamin c',
#   'vitamin pp',
#   'vitamin b5',
#   'acid folic'],
#  ['omeprazol', 'tinidazol', 'clarithromycin'],
#  ['azithromycin'],
#  ['azithromycin'],
#  ['azithromycin'],
#  ['lansoprazol', 'tinidazol', 'clarithromycin'],
#  ['ivermectin'],
#  ['montelukast natri'],
#  ['montelukast'],
#  ['acetaminofen', 'cafein', 'codein phosphat'],
#  ['rabeprazol'],
#  ['montelukast natri'],
#  ['montelukast'],
#  ['lysozym hydroclorid', 'cetylpyridin clorid'],
#  ['carvedilol'],
#  ['carvedilol'],
#  ['carvedilol'],
#  ['vitamin a',
#   'vitamin d3',
#   'vitamin c',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin pp',
#   'vitamin b6',
#   'b12',
#   'lysin hcl',
#   'cholin bitartrat',
#   'myo-inositol'],
#  ['cefadroxil'],
#  ['prednison'],
#  ['diacerein'],
#  ['calci glucoheptonat', 'vitamin c', 'vitamin pp', 'vitamin d2'],
#  ['calci glucoheptonat', 'vitamin c', 'vitamin pp', 'vitamin d2'],
#  ['calci carbonat',
#   'tribasic calci phosphat',
#   'calci fluorid',
#   'magnesi hydroxyd',
#   'vitamin d3'],
#  ['sucralfat'],
#  ['cefaclor'],
#  ['magnesi hydroxyd', 'nhôm hydroxyd gel', 'nhũ dịch simethicon'],
#  ['magnesi hydroxyd', 'nhôm hydroxyd gel', 'nhũ dịch simethicon'],
#  ['isoniazid'],
#  ['vardenafil'],
#  ['cefpodoxim'],
#  ['cefuroxim'],
#  ['cefuroxim'],
#  ['vitamin a',
#   'vitamin e',
#   'vitamin d2',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin pp',
#   'calci',
#   'phosphor',
#   'l-lysin hydroclorid'],
#  ['calci glucolactat', 'calci carbonat'],
#  ['nhôm phosphat gel'],
#  ['acid ursodeoxycholic'],
#  ['rifampicin'],
#  ['fluocinolone acetonide', 'neomycin sulfat'],
#  ['gentamicin sulfat'],
#  ['paracetamol', 'ibuprofen'],
#  ['paracetamol'],
#  ['thiamin  mononitrat'],
#  ['pyridoxin hydroclorid'],
#  ['eucalyptol', 'menthol', 'methyl salicylat', 'camphor'],
#  ['paracetamol'],
#  ['sắt', 'acid folic'],
#  ['magnesi lactat dihydrat', 'pyridoxin hydroclorid'],
#  ['mebendazol'],
#  ['paracetamol'],
#  ['celecoxib'],
#  ['diacerein'],
#  ['paracetamol', 'pseudoephedrin hcl', 'triprolidine hydrocloride'],
#  ['cefuroxim'],
#  ['cetirizin dihydroclorid'],
#  ['clarithromycin'],
#  ['paracetamol', 'pseudoephedrin hydroclorid'],
#  ['dexamethason acetat'],
#  ['pseudoephedrin hcl', 'clorpheniramin maleat'],
#  ['spiramycin 1,5m.iu'],
#  ['spiramycin 3m.iu'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['dexamethason acetat'],
#  ['dexamethason acetat'],
#  ['dexamethason acetat'],
#  ['dextromethorphan hydrobromid', 'diprophyllin', 'lysozym hydroclorid'],
#  ['hoàng liên', 'mộc hương'],
#  ['dipotasium glycyrrhizinate',
#   'chlopheniramin maleat',
#   'pseudoephedrin hcl',
#   'caphein anhydrous'],
#  ['clarithromycin'],
#  ['spiramycin'],
#  ['spiramycin'],
#  ['acid ascorbic'],
#  ['levomepromazin'],
#  ['paracetamol'],
#  ['dimenhydrinat'],
#  ['cao đặc nhân trần tía', 'bột tảo spirulina'],
#  ['ciprofloxacin'],
#  ['paracetamol'],
#  ['bromhexin hydroclorid'],
#  ['bromhexin hcl'],
#  ['cefaclor'],
#  ['acid  ascorbic'],
#  ['cinnarizin'],
#  ['diclofenac natri'],
#  ['acridon acetic acid', 'n-methylglucamin'],
#  ['prednisolon'],
#  ['prednisolon'],
#  ['terpin hydrat', 'dexromethorphan hydrobromid'],
#  ['amlodipin'],
#  ['cefotaxim'],
#  ['vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin d3',
#   'vitamin c'],
#  ['cefadroxil'],
#  ['cefixime'],
#  ['glycerin guaiacolat', 'codein phosphat'],
#  ['omeprazol'],
#  ['paracetamol', 'codein phosphat hemihydrat'],
#  ['paracetamol', 'cafein', 'phenylephrin.hcl'],
#  ['paracetamol', 'ibuprofen'],
#  ['paracetamol', 'dextromethorphan.hbr', 'pseudoephedrin.hcl'],
#  ['paracetamol',
#   'dextromethorphan.hbr',
#   'pseudoephedrin.hcl',
#   'chlorpheniramin maleat'],
#  ['trimetazidin.2hcl'],
#  ['vitamin c'],
#  ['cephalexin mono hydrat'],
#  ['ibuprofen'],
#  ['lidocain hydroclorid'],
#  ['bột đông trùng hạ thảo'],
#  ['acyclovir'],
#  ['terpin hydrat', 'codein phosphat'],
#  ['diacerein'],
#  ['vitamin a',
#   'vitamin e',
#   'vitamin b1',
#   'vitamin b2',
#   'natri chondroitin sulfat',
#   'cholin bitartrate'],
#  ['acid tranexamic'],
#  ['silymarin'],
#  ['tadalafil'],
#  ['bionic tige bone powder'],
#  ['cao đặc tiêu đờm bổ phế',
#   'bạch linh',
#   'bán hạ',
#   'thiên môn đông',
#   'bách bộ'],
#  ['clopidogrel bisulfat'],
#  ['paracetamol', 'codein phosphat', 'cafein monohydrat'],
#  ['atorvastatin calcium trihydrat'],
#  ['cao đặc mộc hoa trắng', 'berberin clorid', 'cao mộc hương'],
#  ['spiramycin'],
#  ['metformin hcl'],
#  ['adrenalinml'],
#  ['calci clorid'],
#  ['cimetidin'],
#  ['cloramphenicol'],
#  ['dextromethorphan hydrobromid', 'guaifenesin'],
#  ['dexamethason natri phosphatml'],
#  ['diphenhydramin hydrocloridml'],
#  ['gentamicin sulfat'],
#  ['lidocain hydroclorid'],
#  ['naphazolin hydroclorid'],
#  ['papaverin hydroclorid'],
#  ['thiamin hydroclorid',
#   'pyridoxin hydroclorid',
#   'riboflavin natri phosphat',
#   'nicotinamid',
#   'dexpantheol'],
#  ['vinpocetin'],
#  ['cyanocobalamin'],
#  ['menadion natribisulfitml'],
#  ['bột mịn nhân sâm', 'bột mịn tam thất'],
#  ['omeprazol'],
#  ['cao bạch quả'],
#  ['albendazol'],
#  ['natri chondroitin sulfat',
#   'cholin hydrotartrat',
#   'retinol palmitat',
#   'riboflavin',
#   'thiamin hcl'],
#  ['calci glubionat'],
#  ['levofloxacin'],
#  ['natri clorid'],
#  ['natri clorid'],
#  ['nước cất pha tiêm'],
#  ['piracetam'],
#  ['các axit amin'],
#  ['betamethason dipropionat1 tuýp', 'acid salicylictuýp'],
#  ['chlorpheniramine'],
#  ['ketoconazol'],
#  ['magnesium trisilicate khan', 'aluminium hydroxide'],
#  ['cefaclor'],
#  ['cefotaxim'],
#  ['kim tiền thảo'],
#  ['nhân trần'],
#  ['râu ngô'],
#  ['ich mẫu'],
#  ['brinzolamid'],
#  ['lidocain hydroclorid'],
#  ['lidocain hydroclorid'],
#  ['pethidin hcl'],
#  ['cao ginkgo biloba'],
#  ['ribavirin'],
#  ['sắt  fumarat',
#   'acid folic',
#   'vitamin b12',
#   'vitamin b6',
#   'vitamin c',
#   'đồng sulfat'],
#  ['clarithromycin'],
#  ['natri chondroitin sulfat',
#   'cholin hydrotartrat',
#   'vitamin a',
#   'vitamin e',
#   'vitamin c',
#   'kẽm',
#   'đồng',
#   'lecithin'],
#  ['paracetamol'],
#  ['paracetamol'],
#  ['lysin', 'các vitamin và khoáng chất'],
#  ['beta caroten', 'vitamin e', 'vitamin c', 'selen'],
#  ['dầu mù u', 'mỡ trăn', 'vitamin e acetat'],
#  ['bột hải sâm thủy phân', 'vitamin b1', 'vitamin b6'],
#  ['ergocalciferol'],
#  ['methyldopa'],
#  ['lisinopril dihydrat'],
#  ['valsartan'],
#  ['spiramycin 1,5miu'],
#  ['spiramycin 3 miu'],
#  ['cefuroxim acetil'],
#  ['cefuroxim acetil'],
#  ['glimepirid'],
#  ['lansoprazol vi hạt bao tan trong ruột'],
#  ['l- cystin'],
#  ['paracetamol', 'thiamin hydrochlorid', 'chlorpheniramin maleat'],
#  ['salbutamol sulfat'],
#  ['serratiopeptidase'],
#  ['simvastatin'],
#  ['thiamin mononitrat'],
#  ['tobramycin', 'dexamethason'],
#  ['tobramycin'],
#  ['natri clorid am'],
#  ['kẽm sulfat'],
#  ['amlodipin'],
#  ['cao actiso', 'cao biển súc', 'cao bìm bìm'],
#  ['biphenyl dimethyl dicarboxylat'],
#  ['prednisolon'],
#  ['paracetamol', 'vitamin c'],
#  ['paracetamol', 'vitamin c'],
#  ['prednisolon'],
#  ['paracetamol', 'pseudoephedrin hcl', 'chlopheniramin maleat'],
#  ['vitamin c'],
#  ['allopurinol'],
#  ['colchicin'],
#  ['atorvasstatin'],
#  ['atorvastatin'],
#  ['metoclopamid hydroclorid'],
#  ['mifepriston'],
#  ['prednisolon'],
#  ['risedronat natri'],
#  ['natri docusat'],
#  ['natri docusat'],
#  ['arginin hcl'],
#  ['paracetamol', 'thiamin mononitrat', 'clorpheniramin'],
#  ['cao ginkgo biloba'],
#  ['lansoprazol'],
#  ['losartan kali', 'hydroclorothiazid'],
#  ['omeprazol'],
#  ['omeprazol'],
#  ['pantoprazol'],
#  ['allopurinol'],
#  ['trimetazidine hydroclorid'],
#  ['acarbose'],
#  ['valsartan'],
#  ['simvastatin'],
#  ['silymarin'],
#  ['biphenyl dimethyl dicarboxylate'],
#  ['eperison hydroclorid'],
#  ['l-ornithin l-aspartat', 'tocopherol acetat'],
#  ['levofloxacin hemihydrat'],
#  ['arginin tidiacicat'],
#  ['biphenyl dimethyl dicarboxylat'],
#  ['desloratadin'],
#  ['fexofenadin hydroclorid'],
#  ['clindamycin hcl'],
#  ['prednisolon'],
#  ['cao chiết ginkgo biloba', 'heptaminol hcl', 'troxerutin'],
#  ['cao chiết chuẩn độ của centella asiatica',
#   'hydrocortison acetat',
#   'neomycin'],
#  ['ceftazidime'],
#  ['ceftriaxon natri', 'sulbactam natri'],
#  ['levofloxacin hemihydrat'],
#  ['nifedipin'],
#  ['alendronic acid'],
#  ['phân đoạn flavonoid tinh khiết', 'hesperidin'],
#  ['metformin hcl'],
#  ['gabapentin'],
#  ['cefuroxim'],
#  ['cefuroxim'],
#  ['atorvastatin'],
#  ['sulfamethoxazol', 'trimethoprim'],
#  ['cefixim'],
#  ['cefixim'],
#  ['phenoxymethyl penicilin kali'],
#  ['terpin hydrat', 'codein base'],
#  ['cao khô bạch quả'],
#  ['glucose monohydrat'],
#  ['alpha-chymotrypsin'],
#  ['triprolidin hcl', 'pseudoephedrin hcl'],
#  ['flunarizin'],
#  ['cetirizin hydrochlorid'],
#  ['cetirizin hydroclorid'],
#  ['paracetamol'],
#  ['loratadin'],
#  ['loratadin'],
#  ['methionin'],
#  ['paracetamol', 'phenylephrinhcl', 'dextromethorphan hbr'],
#  ['nhôm hydroxyd gel khô', 'magnesi hydroxyd'],
#  ['paracetamol', 'dextromethorphan hbr', 'clorpheniramin'],
#  ['paracetamol', 'dextromethorphan hbr', 'loratadin'],
#  ['thiamin mononitrat'],
#  ['pyridoxin hydroclorid'],
#  ['paracetamol', 'ibuprofen'],
#  ['acid mefenamic'],
#  ['sodium chloride',
#   'potassium chloride',
#   'sodium bicarbonate',
#   'dextrose anhydrous'],
#  ['nhôm hydroxyd- magnesi carbonat', 'dimethylpolysiloxan', 'dicyclomin hcl'],
#  ['diclofenac sodium'],
#  ['vitamin e', 'vitamin b1', 'vitamin b6', 'b12'],
#  ['amlodipin'],
#  ['berberin clorid', 'mộc hương', 'ba chẽ'],
#  ['digoxin'],
#  ['thiamin nitrat'],
#  ['pyridoxin hcl'],
#  ['nicotinamid'],
#  ['cetirizin dihydrochlorid'],
#  ['cefadroxil monohydrat'],
#  ['dexamethason acetat'],
#  ['dexpanthenol', 'biotin'],
#  ['arginin hcl'],
#  ['cefixim trihydrat'],
#  ['cefixim trihydrat'],
#  ['cefuroxim acetil'],
#  ['nhân sâm',
#   'đương qui',
#   'bạch truật',
#   'bạch thược',
#   'phục linh',
#   'xuyên khung',
#   'cam thảo',
#   'thục địa'],
#  ['celecoxib'],
#  ['acid fusidic', 'betamethason dipropionat'],
#  ['paracetamol'],
#  ['dextromethorphan hbr'],
#  ['aceclofenac'],
#  ['gabapentin'],
#  ['loperamid hydroclorid'],
#  ['alpisarin'],
#  ['desloratadin'],
#  ['cao khô lá sen', 'cao khô lá vông'],
#  ['rotundin', 'cao khô lá sen', 'cao khô lá vông'],
#  ['clozapin'],
#  ['cao khô solvella',
#   'nhân trần',
#   'hoàng cầm',
#   'uất kim',
#   'binh lang',
#   'chỉ thực',
#   'hậu phác',
#   'bột mộc hương',
#   'bột đại hoàng'],
#  ['cimetidin'],
#  ['doxycyclin hydroclorid'],
#  ['cardus marianus extract',
#   'silybin',
#   'vitamin b1',
#   'vitamin b6',
#   'vitamin pp',
#   'vitamin b5',
#   'vitamin b2'],
#  ['cao khô bạch quả', 'cao đặc đinh lăng'],
#  ['lincomycin hydroclorid'],
#  ['metronidazol', 'cloramphenicol', 'dexamethason acetat', 'nystatin'],
#  ['vitamin a',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b6',
#   'vitamin d3',
#   'vitamin pp',
#   'calci',
#   'phosphor',
#   'kẽm',
#   'lysin hcl'],
#  ['paracetamol', 'codein phosphat'],
#  ['vitamin a',
#   'vitamin d3',
#   'vitamin c',
#   'vitamin b1',
#   'vitamin b2',
#   'vitamin b5',
#   'vitamin pp',
#   'b12',
#   'vitamin b6',
#   'đồng',
#   'sắt',
#   'acid folic',
#   'vitamin e',
#   'magnesi',
#   'kẽm',
#   'calci',
#   'mangan'],
#  ['cao cardus marianus',
#   'thiamin hydroclorid',
#   'riboflavin',
#   'calci pantothenat',
#   'pyridoxin hydroclorid',
#   'nicotinamid'],
#  ['calci gluconat',
#   'sắt',
#   'dl-a tocopheryl acetat',
#   'folic acid',
#   'vitamin c'],
#  ['terpin hydrat', 'codein'],
#  ['alpha lipoic acid'],
#  ['alpha lipoic acid'],
#  ...]

# %%
# unit test for UltimateAPIRegex
def test(s):
	pattern = r"^(?=.*\d)(?=.*\bvitamin\b)|^(\d|,|-|\s)+(?!\d).*|^(?!\d).*$"
	return re.match(pattern, s)

for idx, l in enumerate(api_list):
	for s in l:
		if not test(s):
			print("Failed at index: {}, string: {}".format(idx, s))
print("Test passed")
# Out:
# Test passed
